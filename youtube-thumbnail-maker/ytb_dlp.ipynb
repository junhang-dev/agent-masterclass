# %%
import yt_dlp

url = "https://youtu.be/aR20FWCCjAs?list=TLGG_CRdAXY7RJIwMTEyMjAyNQ"

ydl_opts = {
    "format": "bestvideo[height<=1080]",
    "outtmpl": "./temp.%(ext)s",
    "merge_output_format": "mp4", # 병합 시 mp4로 출력
    "postprocessors": [
        {
        "key": "FFmpegVideoConvertor",
        "preferedformat": "mp4", # mp4로 변환
        }
    ],
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    info = ydl.extract_info(url, download=True)
title = info.get("title", "Unknown")
print(f"{title} 다운로드 완료")
# Out:
# [YoutubeYtBe] Extracting URL: https://youtu.be/aR20FWCCjAs?list=TLGG_CRdAXY7RJIwMTEyMjAyNQ
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=aR20FWCCjAs&list=TLGG_CRdAXY7RJIwMTEyMjAyNQ&feature=youtu.be
# [youtube:tab] Downloading playlist TLGG_CRdAXY7RJIwMTEyMjAyNQ - add --no-playlist to download just the video aR20FWCCjAs
# [youtube:tab] TLGG_CRdAXY7RJIwMTEyMjAyNQ: Downloading webpage
# [download] Downloading playlist: Untitled List
# [youtube:tab] TLGG_CRdAXY7RJIwMTEyMjAyNQ page 1: Downloading API JSON
# [youtube:tab] Playlist Untitled List: Downloading 1 items of 1
# [download] Downloading item 1 of 1
# [youtube] Extracting URL: https://www.youtube.com/watch?v=aR20FWCCjAs
# [youtube] aR20FWCCjAs: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one. To silence this warning, you can use  --extractor-args "youtube:player_client=default"
# [youtube] aR20FWCCjAs: Downloading android sdkless player API JSON
# [youtube] aR20FWCCjAs: Downloading web safari player API JSON
# WARNING: [youtube] aR20FWCCjAs: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [youtube] aR20FWCCjAs: Downloading m3u8 information
# WARNING: [youtube] aR20FWCCjAs: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# [info] aR20FWCCjAs: Downloading 1 format(s): 399
# [download] Sleeping 5.00 seconds as required by the site...
# [download] Destination: temp.mp4
# [download] 100% of  279.44MiB in 00:00:32 at 8.57MiB/s
# [VideoConvertor] Not converting media file "temp.mp4"; already is in target format mp4
# [download] Finished downloading playlist: Untitled List
# Untitled List 다운로드 완료
