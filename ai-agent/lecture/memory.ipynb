# %%
import openai

client = openai.OpenAI()
messages = []

# %%
def call_ai():
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages,
    )
    message = response.choices[0].message.content
    messages.append({"role": "assistant", "content": message})
    print(f"AI: {message}")

# %%
while True:
    message = input("Send a message to the LLM...")
    if message == "quit" or message == "q":
        break
    else:
        messages.append({"role": "user", "content": message})
        print(f"User: {message}")
        call_ai()
# Out:
# User: my name is jun
# AI: Nice to meet you, Jun! How can I assist you today?
# User: what is my name?
# AI: Your name is Jun. How can I help you today, Jun?
# User: i do data analysis in refinery
# AI: That sounds interesting, Jun! Data analysis in a refinery can involve various tasks such as monitoring production efficiency, analyzing operational data, optimizing processes, and ensuring safety compliance. What specific aspects of data analysis do you work on, or is there something in particular you would like to discuss?
# User: all of parts, reliability/operation/optimization etc...
# AI: That’s a comprehensive range of responsibilities! Each of those areas plays a crucial role in the overall efficiency and safety of refinery operations. Here’s a brief overview of each aspect:
#
# 1. **Reliability**: This involves analyzing equipment performance data to predict failures and schedule maintenance proactively. Reliability engineering aims to minimize downtime by ensuring that machinery operates within its safe and efficient parameters.
#
# 2. **Operation**: Operational data analysis focuses on monitoring daily activities, production rates, and compliance with safety and environmental regulations. It can also include analyzing process data to identify bottlenecks and improve throughput.
#
# 3. **Optimization**: This entails using data to improve processes, reduce costs, and enhance product quality. Techniques can range from statistical analysis to machine learning, aiming to refine operational parameters for maximum efficiency.
#
# 4. **Safety and Compliance**: Analyzing safety data (like incident reports and near-miss events) is crucial for improving safety protocols and ensuring compliance with industry regulations.
#
# Is there a specific project or challenge you’re currently facing in these areas, or any tools or methodologies you find particularly effective?
